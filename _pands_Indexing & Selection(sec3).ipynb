# %%
import pandas as pd

# %% [markdown]
# Read and show the first five rows from ramen-ratings.scv file (https://www.kaggle.com/datasets/residentmario/ramen-ratings)

# %%
df=pd.read_csv('ramen-ratings.csv')
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# select the country cloumn from the data

# %%
df['Country']
#df.Country
# Out:
# 0          Japan
# 1         Taiwan
# 2            USA
# 3         Taiwan
# 4          India
#           ...
# 2575     Vietnam
# 2576    Thailand
# 2577    Thailand
# 2578    Thailand
# 2579         USA
# Name: Country, Length: 2580, dtype: object

# %% [markdown]
# index based selection

# %% [markdown]
# select first row of data

# %%
df.iloc[0]
# Out:
# Review #                         2580
# Brand                       New Touch
# Variety     T's Restaurant Tantanmen
# Style                             Cup
# Country                         Japan
# Stars                            3.75
# Top Ten                           NaN
# Name: 0, dtype: object

# %% [markdown]
# select first column of data

# %%
df.iloc[:,0]
# Out:
# 0       2580
# 1       2579
# 2       2578
# 3       2577
# 4       2576
#         ...
# 2575       5
# 2576       4
# 2577       3
# 2578       2
# 2579       1
# Name: Review #, Length: 2580, dtype: int64

# %% [markdown]
# select first 3 row of data

# %%
df.iloc[:3,:]
# Out:
#    Review #      Brand                                            Variety  \
# 0      2580  New Touch                          T's Restaurant Tantanmen
# 1      2579   Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2      2578     Nissin                      Cup Noodles Chicken Vegetable
#
#   Style Country Stars Top Ten
# 0   Cup   Japan  3.75     NaN
# 1  Pack  Taiwan     1     NaN
# 2   Cup     USA  2.25     NaN

# %% [markdown]
# select last column of data

# %%
df.iloc[:,-1]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2575    NaN
# 2576    NaN
# 2577    NaN
# 2578    NaN
# 2579    NaN
# Name: Top Ten, Length: 2580, dtype: object

# %% [markdown]
# fancy indexing

# %%
df.iloc[[1,5,50],:]
# Out:
#     Review #          Brand  \
# 1       2579       Just Way
# 5       2575  Samyang Foods
# 50      2530         Ottogi
#
#                                               Variety Style      Country  \
# 1   Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack       Taiwan
# 5                              Kimchi song Song Ramen  Pack  South Korea
# 50           Ppushu Ppushu Noodle Snack Honey Butter   Pack  South Korea
#
#    Stars Top Ten
# 1      1     NaN
# 5   4.75     NaN
# 50     2     NaN

# %% [markdown]
# select last 10 rows of data

# %%
df.iloc[-10:,:]
# Out:
#       Review #     Brand                                            Variety  \
# 2570        10     Smack                                     Vegetable Beef
# 2571         9     Sutah                                         Cup Noodle
# 2572         8    Tung-I                   Chinese Beef Instant Rice Noodle
# 2573         7   Ve Wong                                      Mushroom Pork
# 2574         6     Vifon                                           Nam Vang
# 2575         5     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 2576         4   Wai Wai                     Oriental Style Instant Noodles
# 2577         3   Wai Wai                                     Tom Yum Shrimp
# 2578         2   Wai Wai                               Tom Yum Chili Flavor
# 2579         1  Westbrae                                         Miso Ramen
#
#      Style      Country Stars Top Ten
# 2570  Pack          USA   1.5     NaN
# 2571   Cup  South Korea     2     NaN
# ...

# %% [markdown]
# Lable based selection

# %%
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# selaect Brand, Style and stars columns

# %%
df.loc[:,['Brand','Style','Stars']]
# Out:
#                Brand Style Stars
# 0          New Touch   Cup  3.75
# 1           Just Way  Pack     1
# 2             Nissin   Cup  2.25
# 3            Wei Lih  Pack  2.75
# 4     Ching's Secret  Pack  3.75
# ...              ...   ...   ...
# 2575           Vifon  Bowl   3.5
# 2576         Wai Wai  Pack     1
# 2577         Wai Wai  Pack     2
# 2578         Wai Wai  Pack     2
# 2579        Westbrae  Pack   0.5
#
# [2580 rows x 3 columns]

# %% [markdown]
# the diffrence between iloc and loc

# %%
df.iloc[1:4]
# Out:
#    Review #     Brand                                            Variety  \
# 1      2579  Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2      2578    Nissin                      Cup Noodles Chicken Vegetable
# 3      2577   Wei Lih                      GGE Ramen Snack Tomato Flavor
#
#   Style Country Stars Top Ten
# 1  Pack  Taiwan     1     NaN
# 2   Cup     USA  2.25     NaN
# 3  Pack  Taiwan  2.75     NaN

# %%
df.loc[1:4]
# Out:
#    Review #           Brand  \
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
